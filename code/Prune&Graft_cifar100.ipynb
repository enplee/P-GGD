# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import os
import collections
import argparse
import sys
import pickle
import numpy as np
import time, datetime
import copy
from thop import profile
from collections import OrderedDict
import shutil
import torch.utils
import torch.utils.data.distributed
from torchvision import datasets, transforms

# %%
import math
import pdb


def conv_bn(inp, oup, stride):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 3, stride, 1, bias=False),
        nn.BatchNorm2d(oup),
        nn.ReLU6(inplace=True)
    )

def conv_1x1_bn(inp, oup):
    return nn.Sequential(
        nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
        nn.BatchNorm2d(oup),
        nn.ReLU6(inplace=True)
    )

def make_divisible(x, divisible_by=8):
    import numpy as np
    return int(np.ceil(x * 1. / divisible_by) * divisible_by)


class InvertedResidual(nn.Module):
    def __init__(self, inp, oup, stride, expand_ratio):
        super(InvertedResidual, self).__init__()
        self.stride = stride
        assert stride in [1, 2]

        hidden_dim = int(inp * expand_ratio)
        self.use_res_connect = self.stride == 1 and inp == oup

        if expand_ratio == 1:
            self.conv = nn.Sequential(
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride, 1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.ReLU6(inplace=True),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )
        else:
            self.conv = nn.Sequential(
                # pw
                nn.Conv2d(inp, hidden_dim, 1, 1, 0, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.ReLU6(inplace=True),
                # dw
                nn.Conv2d(hidden_dim, hidden_dim, 3, stride, 1, groups=hidden_dim, bias=False),
                nn.BatchNorm2d(hidden_dim),
                nn.ReLU6(inplace=True),
                # pw-linear
                nn.Conv2d(hidden_dim, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
            )

    def forward(self, x):
        if self.use_res_connect:
            return x + self.conv(x)
        else:
            return self.conv(x)


class MobileNetV2(nn.Module):
    def __init__(self, compress_rate, n_class=1000, input_size=224, width_mult=1.):
        super(MobileNetV2, self).__init__()
        block = InvertedResidual
        input_channel = 32
        last_channel = 1280
        interverted_residual_setting = [
            # t-ex, c-channel, n-blocknum, s-stride
            [1, 16, 1, 1],
            [6, 24, 2, 2], # NOTE: change stride 1 -> 2 for CIFAR100
            [6, 32, 3, 2],
            [6, 64, 4, 2],
            [6, 96, 3, 1],
            [6, 160, 3, 2],
            [6, 320, 1, 1],
        ]
        self.compress_rate=compress_rate[:]

        # building first layer
        assert input_size % 32 == 0
        # input_channel = make_divisible(input_channel * width_mult)  # first channel is always 32!
        self.last_channel = make_divisible(last_channel * width_mult) if width_mult > 1.0 else last_channel
        self.features = [conv_bn(3, input_channel, 2)]
        # building inverted residual blocks
        cnt=1
        for t, c, n, s in interverted_residual_setting:
            output_channel = make_divisible(c * width_mult) if t > 1 else c
            output_channel = int((1-self.compress_rate[cnt])*output_channel)
            for i in range(n):
                if i == 0:
                    self.features.append(block(input_channel, output_channel, s, expand_ratio=t))
                else:
                    self.features.append(block(input_channel, output_channel, 1, expand_ratio=t))
                input_channel = output_channel
            cnt+=1

        # building last several layers
        self.features.append(conv_1x1_bn(input_channel, self.last_channel))
        # make it nn.Sequential
        self.features = nn.Sequential(*self.features)

        # building classifier
        #self.classifier = nn.Linear(self.last_channel, n_class)
        self.classifier = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(self.last_channel, n_class),
        )

        self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = x.mean(3).mean(2)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()


def mobilenet_v2(compress_rate,n_class=1000):
    model = MobileNetV2(compress_rate=compress_rate,n_class=n_class,width_mult=1)
    return model

# %%
print("prepare resNet_50 model...")
def adapt_channel(compress_rate, num_layers):

    if num_layers==56:
        stage_repeat = [9, 9, 9]
        stage_out_channel = [16] + [16] * 9 + [32] * 9 + [64] * 9
    elif num_layers==110:
        stage_repeat = [18, 18, 18]
        stage_out_channel = [16] + [16] * 18 + [32] * 18 + [64] * 18

    stage_oup_cprate = []
    stage_oup_cprate += [compress_rate[0]]
    for i in range(len(stage_repeat)-1):
        stage_oup_cprate += [compress_rate[i+1]] * stage_repeat[i]
    stage_oup_cprate +=[0.] * stage_repeat[-1]
    mid_cprate = compress_rate[len(stage_repeat):]

    overall_channel = []
    mid_channel = []
    for i in range(len(stage_out_channel)):
        if i == 0 :
            overall_channel += [int(stage_out_channel[i] * (1-stage_oup_cprate[i]))]
        else:
            overall_channel += [int(stage_out_channel[i] * (1-stage_oup_cprate[i]))]
            mid_channel += [int(stage_out_channel[i] * (1-mid_cprate[i-1]))]

    return overall_channel, mid_channel


def conv3x3(in_planes, out_planes, stride=1):
    """3x3 convolution with padding"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                     padding=1, bias=False)

def conv1x1(in_planes, out_planes, stride=1):
    """1x1 convolution"""
    return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)


class LambdaLayer(nn.Module):
    def __init__(self, lambd):
        super(LambdaLayer, self).__init__()
        self.lambd = lambd

    def forward(self, x):
        return self.lambd(x)


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, midplanes, inplanes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.inplanes = inplanes
        self.planes = planes
        self.conv1 = conv3x3(inplanes, midplanes, stride)
        self.bn1 = nn.BatchNorm2d(midplanes)
        self.relu1 = nn.ReLU(inplace=True)

        self.conv2 = conv3x3(midplanes, planes)
        self.bn2 = nn.BatchNorm2d(planes)
        self.relu2 = nn.ReLU(inplace=True)
        self.stride = stride

        self.shortcut = nn.Sequential()
        if stride != 1 or inplanes != planes:
            if stride!=1:
                self.shortcut = LambdaLayer(
                    lambda x: F.pad(x[:, :, ::2, ::2],
                                    (0, 0, 0, 0, (planes-inplanes)//2, planes-inplanes-(planes-inplanes)//2), "constant", 0))
            else:
                self.shortcut = LambdaLayer(
                    lambda x: F.pad(x[:, :, :, :],
                                    (0, 0, 0, 0, (planes-inplanes)//2, planes-inplanes-(planes-inplanes)//2), "constant", 0))
            #self.shortcut = LambdaLayer(
            #    lambda x: F.pad(x[:, :, ::2, ::2], (0, 0, 0, 0, planes//4, planes//4),"constant", 0))

            '''self.shortcut = nn.Sequential(
                conv1x1(inplanes, planes, stride=stride),
                #nn.BatchNorm2d(planes),
            )#'''

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        out = self.conv2(out)
        out = self.bn2(out)

        #print(self.stride, self.inplanes, self.planes, out.size(), self.shortcut(x).size())
        out += self.shortcut(x)
        out = self.relu2(out)

        return out


class ResNet(nn.Module):
    def __init__(self, block, num_layers, compress_rate, num_classes=100):
        super(ResNet, self).__init__()
        assert (num_layers - 2) % 6 == 0, 'depth should be 6n+2'
        n = (num_layers - 2) // 6

        self.num_layer = num_layers
        self.overall_channel, self.mid_channel = adapt_channel(compress_rate, num_layers)

        self.layer_num = 0
        self.conv1 = nn.Conv2d(3, self.overall_channel[self.layer_num], kernel_size=3, stride=1, padding=1,
                               bias=False)
        self.bn1 = nn.BatchNorm2d(self.overall_channel[self.layer_num])
        self.relu = nn.ReLU(inplace=True)
        self.layers = nn.ModuleList()
        self.layer_num += 1

        #self.layers = nn.ModuleList()
        self.layer1 = self._make_layer(block, blocks_num=n, stride=1)
        self.layer2 = self._make_layer(block, blocks_num=n, stride=2)
        self.layer3 = self._make_layer(block, blocks_num=n, stride=2)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        if self.num_layer == 56:
            self.fc = nn.Linear(64 * BasicBlock.expansion, num_classes)
        else:
            self.linear = nn.Linear(64 * BasicBlock.expansion, num_classes)


    def _make_layer(self, block, blocks_num, stride):
        layers = []
        layers.append(block(self.mid_channel[self.layer_num - 1], self.overall_channel[self.layer_num - 1],
                                 self.overall_channel[self.layer_num], stride))
        self.layer_num += 1

        for i in range(1, blocks_num):
            layers.append(block(self.mid_channel[self.layer_num - 1], self.overall_channel[self.layer_num - 1],
                                     self.overall_channel[self.layer_num]))
            self.layer_num += 1

        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)

        for i, block in enumerate(self.layer1):
            x = block(x)
        for i, block in enumerate(self.layer2):
            x = block(x)
        for i, block in enumerate(self.layer3):
            x = block(x)

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)

        if self.num_layer == 56:
            x = self.fc(x)
        else:
            x = self.linear(x)

        return x


def resnet_56(compress_rate):
    return ResNet(BasicBlock, 56, compress_rate=compress_rate)

def resnet_110(compress_rate):
    return ResNet(BasicBlock, 110, compress_rate=compress_rate)
# Out:
# prepare resNet_50 model...

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
cudnn.benchmark = True
cudnn.enabled=True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def load_mobilenetv2_model(model, oristate_dict):

    state_dict = model.state_dict()

    last_select_index = None

    all_honey_conv_weight = []

    bn_part_name=['.weight','.bias','.running_mean','.running_var']
    prefix = rank_conv_prefix+'rank_conv'
    subfix = ".npy"

    layer_cnt=1
    conv_cnt=1
    cfg=[1,2,3,4,3,3,1,1]
    for layer, num in enumerate(cfg):
        if layer_cnt==1:
            conv_id=[0,3]
        elif layer_cnt==18:
            conv_id=[0]
        else:
            conv_id=[0,3,6]

        for k in range(num):
            if layer_cnt==18:
                block_name = 'features.' + str(layer_cnt) + '.'
            else:
                block_name = 'features.'+str(layer_cnt)+'.conv.'

            for l in conv_id:
                conv_cnt += 1
                conv_name = block_name + str(l)
                bn_name = block_name + str(l+1)

                conv_weight_name = conv_name + '.weight'
                all_honey_conv_weight.append(conv_weight_name)
                oriweight = oristate_dict[conv_weight_name]
                curweight = state_dict[name_base+conv_weight_name]
                orifilter_num = oriweight.size(0)
                currentfilter_num = curweight.size(0)

                if orifilter_num != currentfilter_num:
                    print('loading rank from: ' + prefix + str(conv_cnt) + subfix)
                    rank = np.load(prefix + str(conv_cnt) + subfix)
                    select_index = np.argsort(rank)[orifilter_num - currentfilter_num:]  # preserved filter id
                    select_index.sort()

                    if (l==6 or (l==0 and layer_cnt!=1) or (l==3 and layer_cnt==1)) and last_select_index is not None:
                        for index_i, i in enumerate(select_index):
                            for index_j, j in enumerate(last_select_index):
                                state_dict[name_base+conv_weight_name][index_i][index_j] = \
                                    oristate_dict[conv_weight_name][i][j]
                            for bn_part in bn_part_name:
                                state_dict[name_base + bn_name + bn_part][index_i] = \
                                    oristate_dict[bn_name + bn_part][i]
                    else:
                        for index_i, i in enumerate(select_index):
                            state_dict[name_base+conv_weight_name][index_i] = \
                                oristate_dict[conv_weight_name][i]
                            for bn_part in bn_part_name:
                                state_dict[name_base + bn_name + bn_part][index_i] = \
                                    oristate_dict[bn_name + bn_part][i]

                    last_select_index = select_index

                elif  (l==6 or (l==0 and layer_cnt!=1) or (l==3 and layer_cnt==1)) and last_select_index is not None:
                    for index_i in range(orifilter_num):
                        for index_j, j in enumerate(last_select_index):
                            state_dict[name_base+conv_weight_name][index_i][index_j] = \
                                oristate_dict[conv_weight_name][index_i][j]
                    for bn_part in bn_part_name:
                        state_dict[name_base + bn_name + bn_part] = \
                            oristate_dict[bn_name + bn_part]
                    last_select_index = None

                else:
                    state_dict[name_base+conv_weight_name] = oriweight
                    for bn_part in bn_part_name:
                        state_dict[name_base + bn_name + bn_part] = \
                            oristate_dict[bn_name + bn_part]
                    last_select_index = None

                state_dict[name_base + bn_name + '.num_batches_tracked'] = oristate_dict[bn_name + '.num_batches_tracked']

            layer_cnt+=1

    for name, module in model.named_modules():
        name = name.replace('module.', '')
        if isinstance(module, nn.Conv2d):
            conv_name = name + '.weight'
            bn_name = list(name[:])
            bn_name[-1] = str(int(name[-1])+1)
            bn_name = ''.join(bn_name)
            if conv_name not in all_honey_conv_weight:
                state_dict[name_base+conv_name] = oristate_dict[conv_name]
                for bn_part in bn_part_name:
                    state_dict[name_base + bn_name + bn_part] = \
                        oristate_dict[bn_name + bn_part]
                state_dict[name_base + bn_name + '.num_batches_tracked'] = oristate_dict[bn_name + '.num_batches_tracked']

        elif isinstance(module, nn.Linear):
            state_dict[name_base+name + '.weight'] = oristate_dict[name + '.weight']
            state_dict[name_base+name + '.bias'] = oristate_dict[name + '.bias']

    model.load_state_dict(state_dict,strict=False)
    print("finish pruning")
    
def adjust_learning_rate(optimizer, epoch, step, len_iter):

    if lr_type == 'step':
        factor = epoch // 30
        if epoch >= 80:
            factor = factor + 1
        lr = learning_rate * (0.1 ** factor)

    elif lr_type == 'cos':  # cos without warm-up
        lr = 0.5 * learning_rate * (1 + math.cos(math.pi * (epoch - 5) / (epochs - 5)))

    elif lr_type == 'exp':
        step = 1
        decay = 0.96
        lr = learning_rate * (decay ** (epoch // step))

    elif lr_type == 'fixed':
        lr = learning_rate
    else:
        raise NotImplementedError

    #Warmup
    if epoch < 5:
        lr = lr * float(1 + step + epoch * len_iter) / (5. * len_iter)

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    if step == 0:
        print('learning_rate: ' + str(lr))

def load_resnet_model(model, oristate_dict, layer):
    cfg = {
        56: [9, 9, 9],
        110: [18, 18, 18],
    }

    state_dict = model.state_dict()

    current_cfg = cfg[layer]
    last_select_index = None

    all_conv_weight = []

    prefix = rank_conv_prefix+'rank_conv'
    subfix = ".npy"

    cnt=1
    for layer, num in enumerate(current_cfg):
        layer_name = 'layer' + str(layer + 1) + '.'
        for k in range(num):
            for l in range(2):

                cnt+=1
                cov_id=cnt

                conv_name = layer_name + str(k) + '.conv' + str(l + 1)
                conv_weight_name = conv_name + '.weight'
                all_conv_weight.append(conv_weight_name)
                oriweight = oristate_dict[conv_weight_name]
                curweight =state_dict[name_base+conv_weight_name]
                orifilter_num = oriweight.size(0)
                currentfilter_num = curweight.size(0)

                if orifilter_num != currentfilter_num:
                    print('loading rank from: ' + prefix + str(cov_id) + subfix)
                    rank = np.load(prefix + str(cov_id) + subfix)
                    select_index = np.argsort(rank)[orifilter_num - currentfilter_num:]  # preserved filter id
                    select_index.sort()

                    if last_select_index is not None:
                        for index_i, i in enumerate(select_index):
                            for index_j, j in enumerate(last_select_index):
                                state_dict[name_base+conv_weight_name][index_i][index_j] = \
                                    oristate_dict[conv_weight_name][i][j]
                    else:
                        for index_i, i in enumerate(select_index):
                            state_dict[name_base+conv_weight_name][index_i] = \
                                oristate_dict[conv_weight_name][i]

                    last_select_index = select_index

                elif last_select_index is not None:
                    for index_i in range(orifilter_num):
                        for index_j, j in enumerate(last_select_index):
                            state_dict[name_base+conv_weight_name][index_i][index_j] = \
                                oristate_dict[conv_weight_name][index_i][j]
                    last_select_index = None

                else:
                    state_dict[name_base+conv_weight_name] = oriweight
                    last_select_index = None

    for name, module in model.named_modules():
        name = name.replace('module.', '')

        if isinstance(module, nn.Conv2d):
            conv_name = name + '.weight'
            if 'shortcut' in name:
                continue
            if conv_name not in all_conv_weight:
                state_dict[name_base+conv_name] = oristate_dict[conv_name]

        elif isinstance(module, nn.Linear):
            state_dict[name_base+name + '.weight'] = oristate_dict[name + '.weight']
            state_dict[name_base+name + '.bias'] = oristate_dict[name + '.bias']

    model.load_state_dict(state_dict)

# %%
print("超参数")
CLASSES = 100
lr_type = 'step'
epochs = 300
batch_size=  256

learning_rate = 0.1
momentum = 0.9
# 0.006
weight_decay = 0.0001
label_smooth = 0.1 
lr_decay_step = '150,225'

best_acc = 0
# "mobilenet_v2" "resnet_56"
arch = "mobilenet_v2"
# "[0.]+[0.4]*2+[0.5]*9+[0.6]*9+[0.7]*9" “[0.]+[0.15]*2+[0.4]*27”"'[0.]+[0.18]*29'"
compress_rate = "[0.]+[0.18]*29"
# "./data/model/Hrank_preTrain/cifar-10/resnet_56.pt.pt"
pretrain_dir = "./data/model/Hrank_preTrain/cifar-100/resnet_56_cifar_100.t7"
save_dir = "PruneGraft_cifar100_press1_"+arch

rank_conv_dir = "./data/model/rank_conv/cifar-100/resnet_56_limit5/"
print(save_dir)
# Out:
# 超参数
# PruneGraft_cifar100_press1_resnet_56

# %%
start_t = time.time()
print("prepare compress_rate")
def process_compress_rate(compress_rate):
    if compress_rate:# 处理args.compress_rate
        import re
        cprate_str = compress_rate
        cprate_str_list = cprate_str.split('+')
        pat_cprate = re.compile(r'\d+\.\d*')
        pat_num = re.compile(r'\*\d+')
        cprate = []
        for x in cprate_str_list:
            num = 1
            find_num = re.findall(pat_num, x)
            if find_num:
                assert len(find_num) == 1
                num = int(find_num[0].replace('*', ''))
            find_cprate = re.findall(pat_cprate, x)
            assert len(find_cprate) == 1
            cprate += [float(find_cprate[0])] * num

        compress_rate = cprate
        return compress_rate
compress_rate = process_compress_rate(compress_rate)
print('compress_rate:' + str(compress_rate))
# Out:
# prepare compress_rate
# compress_rate:[0.0, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18, 0.18]

# %%
print("=====> Building model")
if arch == "mobilenet_v2":
    net_1 = mobilenet_v2(compress_rate,n_class=10)
    net_2 = mobilenet_v2(compress_rate,n_class=10)
    net_1.to(device)
    net_2.to(device)
    
    rank_conv_prefix = "./data/model/rank_conv/mobileNetV2_limit5/"
    name_base=''

    print('resuming from pretrain model')
    origin_model = mobilenet_v2(compress_rate=[0.] * 100,n_class=10).cuda()
    ckpt = torch.load("./data/model/PruneGraft_cifar10_MobileNetV2_preTrain/best_9.t7")
    # ckpt = {k:v for k,v in ckpt.items() if "classifier" not in k}
    ckpt = ckpt["net"]

    origin_model.load_state_dict(ckpt)
    oristate_dict = origin_model.state_dict()
    load_mobilenetv2_model(net_1,oristate_dict)
    load_mobilenetv2_model(net_2,oristate_dict)
if arch == "resnet_56":
    net_1 = resnet_56(compress_rate)
    net_2 = resnet_56(compress_rate)
    net_1.to(device)
    net_2.to(device)
    

    
    input_image_size=32
    input_image = torch.randn(1, 3, input_image_size, input_image_size).cuda()
    flops, params = profile(net_2, inputs=(input_image,))
    print('Params: %.2f' % (params))
    print('Flops: %.2f' % (flops))

    input_image_size=32
    input_image = torch.randn(1, 3, input_image_size, input_image_size).cuda()
    flops, params = profile(net_1, inputs=(input_image,))
    print('Params: %.2f' % (params))
    print('Flops: %.2f' % (flops))
    rank_conv_prefix = rank_conv_dir
    name_base=''
    
    origin_model = resnet_56(compress_rate=[0.] * 100).cuda()
    
    input_image_size=32
    input_image = torch.randn(1, 3, input_image_size, input_image_size).cuda()
    flops, params = profile(origin_model, inputs=(input_image,))
    print('Params: %.2f' % (params))
    print('Flops: %.2f' % (flops))
    
    ckpt = torch.load(pretrain_dir, map_location='cuda:0')
    origin_model.load_state_dict(ckpt['net'])

    
    oristate_dict = origin_model.state_dict()
    load_resnet_model(net_1, oristate_dict, 56)
    print("-------------------")
    load_resnet_model(net_2, oristate_dict, 56)
# Out:
# =====> Building model
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_bn() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.LambdaLayer'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.BasicBlock'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.Sequential'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [WARN] Cannot find rule for <class '__main__.ResNet'>. Treat it as zero Macs and zero Params.
# Params: 666007.00
# Flops: 90355520.00
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_bn() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.LambdaLayer'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.BasicBlock'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.Sequential'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [WARN] Cannot find rule for <class '__main__.ResNet'>. Treat it as zero Macs and zero Params.
# Params: 666007.00
# Flops: 90355520.00
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_bn() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.Sequential'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.BasicBlock'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class '__main__.LambdaLayer'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [WARN] Cannot find rule for <class '__main__.ResNet'>. Treat it as zero Macs and zero Params.
# Params: 858868.00
# Flops: 126560576.00
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv2.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv3.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv4.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv5.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv6.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv7.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv8.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv9.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv10.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv11.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv12.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv13.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv14.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv15.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv16.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv17.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv18.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv19.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv20.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv21.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv22.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv23.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv24.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv25.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv26.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv27.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv28.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv29.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv30.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv31.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv32.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv33.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv34.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv35.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv36.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv37.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv38.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv40.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv42.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv44.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv46.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv48.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv50.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv52.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv54.npy
# -------------------
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv2.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv3.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv4.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv5.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv6.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv7.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv8.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv9.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv10.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv11.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv12.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv13.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv14.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv15.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv16.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv17.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv18.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv19.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv20.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv21.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv22.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv23.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv24.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv25.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv26.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv27.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv28.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv29.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv30.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv31.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv32.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv33.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv34.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv35.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv36.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv37.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv38.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv40.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv42.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv44.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv46.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv48.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv50.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv52.npy
# loading rank from: ./data/model/rank_conv/cifar-100/resnet_56_limit5/rank_conv54.npy

# %%
class CrossEntropyLabelSmooth(nn.Module):

  def __init__(self, num_classes, epsilon):
    super(CrossEntropyLabelSmooth, self).__init__()
    self.num_classes = num_classes
    self.epsilon = epsilon
    self.logsoftmax = nn.LogSoftmax(dim=1)

  def forward(self, inputs, targets):
    log_probs = self.logsoftmax(inputs)
    targets = torch.zeros_like(log_probs).scatter_(1, targets.unsqueeze(1), 1)
    targets = (1 - self.epsilon) * targets + self.epsilon / self.num_classes
    loss = (-targets * log_probs).mean(0).sum()
    return loss   


criterion_1 = nn.CrossEntropyLoss()
criterion_1 = criterion_1.cuda()
criterion_smooth_1 = CrossEntropyLabelSmooth(CLASSES, 0.1)
criterion_smooth_1 = criterion_smooth_1.cuda()

criterion_2 = nn.CrossEntropyLoss()
criterion_2 = criterion_2.cuda()
criterion_smooth_2 = CrossEntropyLabelSmooth(CLASSES, 0.1)
criterion_smooth_2 = criterion_smooth_2.cuda()

optimizer_1 = torch.optim.SGD(net_1.parameters(), learning_rate, momentum=momentum, weight_decay=weight_decay)
optimizer_2 = torch.optim.SGD(net_2.parameters(), 0.1, momentum=momentum, weight_decay=0.0001)
lr_decay_step = list(map(int, lr_decay_step.split(',')))
scheduler_1 = torch.optim.lr_scheduler.MultiStepLR(optimizer_1, milestones=lr_decay_step, gamma=0.1)
scheduler_2 = torch.optim.lr_scheduler.MultiStepLR(optimizer_2, milestones=lr_decay_step, gamma=0.1)

lr_scheduler_1 = torch.optim.lr_scheduler.StepLR(optimizer_1, step_size=60, gamma=0.1)
lr_scheduler_2 = torch.optim.lr_scheduler.StepLR(optimizer_2, step_size=60, gamma=0.1)

# %%
print('load training data')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR100(root='./data/cifar-100/', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR100(root='./data/cifar-100/', train=False, download=True, transform=transform_test)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True,drop_last=False)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False,drop_last=False)
# Out:
# load training data
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def entropy(x, n=10):
    x = x.reshape(-1)
    scale = (x.max() - x.min()) / n
    entropy = 0
    for i in range(n):
        p = torch.sum((x >= x.min() + i * scale) * (x < x.min() + (i + 1) * scale), dtype=torch.float) / len(x)
        if p != 0:
            entropy -= p * torch.log(p)
    return float(entropy.cpu())

def train(epoch,i,net,optimizer,scheduler,criterion):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    
    num_iter = len(trainloader)
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        
#         adjust_learning_rate(optimizer, epoch, batch_idx, num_iter)
        
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        if batch_idx % 1000 == 1000 - 1 or 1000 == trainloader.__len__() - 1:
            print('Loss: %.3f | Acc: %.3f%% (%d/%d)' % (
                train_loss / (batch_idx + 1), 100. * correct / total, correct, total))
    scheduler.step()
    
def test(epoch,net,i,criterion):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    acc = 100. * correct / total
    if acc > best_acc:
        best_acc = acc
        state = {
            'net': net.state_dict(),
            'acc': acc
        }
        torch.save(state, './data/model/'+save_dir+'/best_%d.t7' % (epoch))
    print('Network:%d    epoch:%d    accuracy:%.3f    best:%.3f' % (i, epoch, acc, best_acc))

def grafting(net, epoch,i):
    while True:
        try:
            checkpoint = torch.load('./data/model/'+save_dir+'/ckpt%d_%d.t7' % (i - 1, epoch))['net']
            break
        except:
            time.sleep(10)
    model = collections.OrderedDict()
    w = 1 
    for i, (key, u) in enumerate(net.state_dict().items()):
        if 'conv' in key and 'weight' in key:
            w = round(0.4 / np.pi * np.arctan(500 * (entropy(u) - entropy(checkpoint[key]))) + 0.5, 2)
        model[key] = u * w + checkpoint[key] * (1 - w)
        
    net.load_state_dict(model)
    
# for epoch in range(200):
#     scheduler_1.step()
#     scheduler_2.step()

# %%
for epoch in range(300):
    train(epoch,1,net_1,optimizer_1,scheduler_1,criterion_smooth_1)
    test(epoch,net_1,1,criterion_1)
    state = {
        'net': net_1.state_dict(),
    }
    torch.save(state, './data/model/'+save_dir+'/ckpt%d_%d.t7' % ( 1, epoch))
    
    train(epoch,2,net_2,optimizer_2,scheduler_2,criterion_smooth_2)
    test(epoch,net_2,2,criterion_2)
    state = {
        'net': net_2.state_dict(),
        
    }
    torch.save(state, './data/model/'+save_dir+'/ckpt%d_%d.t7' % ( 0, epoch))
    
    grafting(net_1,epoch,1)
    grafting(net_2,epoch,2)
# Out:
# learning_rate: 0.00010204081632653062
# Network:1    epoch:0    accuracy:42.420    best:42.420
# learning_rate: 0.00010204081632653062
# Network:2    epoch:0    accuracy:27.020    best:42.420
# learning_rate: 0.020102040816326532
# Network:1    epoch:1    accuracy:45.400    best:45.400
# learning_rate: 0.020102040816326532
# Network:2    epoch:1    accuracy:40.710    best:45.400
# learning_rate: 0.04010204081632653
# Network:1    epoch:2    accuracy:50.210    best:50.210
# learning_rate: 0.04010204081632653
# Network:2    epoch:2    accuracy:49.710    best:50.210
# learning_rate: 0.06010204081632654
# Network:1    epoch:3    accuracy:50.410    best:50.410
# learning_rate: 0.06010204081632654
# Network:2    epoch:3    accuracy:54.120    best:54.120
# learning_rate: 0.08010204081632653
# Network:1    epoch:4    accuracy:51.750    best:54.120
# learning_rate: 0.08010204081632653
# Network:2    epoch:4    accuracy:51.110    best:54.120
# learning_rate: 0.1
# Network:1    epoch:5    accuracy:56.360    best:56.360
# learning_rate: 0.1
# Network:2    epoch:5    accuracy:55.300    best:56.360
# learning_rate: 0.1
# Network:1    epoch:6    accuracy:56.270    best:56.360
# learning_rate: 0.1
# Network:2    epoch:6    accuracy:54.900    best:56.360
# learning_rate: 0.1
# Network:1    epoch:7    accuracy:57.320    best:57.320
# learning_rate: 0.1
# Network:2    epoch:7    accuracy:59.230    best:59.230
# learning_rate: 0.1
# Network:1    epoch:8    accuracy:58.890    best:59.230
# learning_rate: 0.1
# Network:2    epoch:8    accuracy:59.150    best:59.230
# learning_rate: 0.1
# Network:1    epoch:9    accuracy:60.820    best:60.820
# learning_rate: 0.1
# Network:2    epoch:9    accuracy:57.350    best:60.820
# learning_rate: 0.1
# Network:1    epoch:10    accuracy:56.120    best:60.820
# learning_rate: 0.1
# Network:2    epoch:10    accuracy:59.700    best:60.820
# learning_rate: 0.1
# Network:1    epoch:11    accuracy:59.240    best:60.820
# learning_rate: 0.1
# Network:2    epoch:11    accuracy:58.970    best:60.820
# learning_rate: 0.1
# Network:1    epoch:12    accuracy:60.520    best:60.820
# learning_rate: 0.1
# Network:2    epoch:12    accuracy:60.650    best:60.820
# learning_rate: 0.1
# Network:1    epoch:13    accuracy:59.230    best:60.820
# learning_rate: 0.1
# Network:2    epoch:13    accuracy:57.490    best:60.820
# learning_rate: 0.1
# Network:1    epoch:14    accuracy:56.170    best:60.820
# learning_rate: 0.1
# Network:2    epoch:14    accuracy:61.060    best:61.060
# learning_rate: 0.1
# Network:1    epoch:15    accuracy:60.610    best:61.060
# learning_rate: 0.1
# Network:2    epoch:15    accuracy:60.210    best:61.060
# learning_rate: 0.1
# Network:1    epoch:16    accuracy:60.260    best:61.060
# learning_rate: 0.1
# Network:2    epoch:16    accuracy:60.690    best:61.060
# learning_rate: 0.1
# Network:1    epoch:17    accuracy:59.050    best:61.060
# learning_rate: 0.1
# Network:2    epoch:17    accuracy:58.800    best:61.060
# learning_rate: 0.1
# Network:1    epoch:18    accuracy:59.860    best:61.060
# learning_rate: 0.1
# Network:2    epoch:18    accuracy:60.730    best:61.060
# learning_rate: 0.1
# Network:1    epoch:19    accuracy:56.890    best:61.060
# learning_rate: 0.1
# Network:2    epoch:19    accuracy:60.330    best:61.060
# learning_rate: 0.1
# Network:1    epoch:20    accuracy:59.340    best:61.060
# learning_rate: 0.1
# Network:2    epoch:20    accuracy:60.520    best:61.060
# learning_rate: 0.1
# Network:1    epoch:21    accuracy:62.090    best:62.090
# learning_rate: 0.1
# Network:2    epoch:21    accuracy:58.450    best:62.090
# learning_rate: 0.1
# Network:1    epoch:22    accuracy:60.710    best:62.090
# learning_rate: 0.1
# Network:2    epoch:22    accuracy:58.580    best:62.090
# learning_rate: 0.1
# Network:1    epoch:23    accuracy:60.130    best:62.090
# learning_rate: 0.1
# Network:2    epoch:23    accuracy:60.900    best:62.090
# learning_rate: 0.1
# Network:1    epoch:24    accuracy:61.150    best:62.090
# learning_rate: 0.1
# Network:2    epoch:24    accuracy:60.780    best:62.090
# learning_rate: 0.1
# Network:1    epoch:25    accuracy:58.960    best:62.090
# learning_rate: 0.1
# Network:2    epoch:25    accuracy:58.180    best:62.090
# learning_rate: 0.1
# Network:1    epoch:26    accuracy:59.720    best:62.090
# learning_rate: 0.1
# Network:2    epoch:26    accuracy:59.660    best:62.090
# learning_rate: 0.1
# Network:1    epoch:27    accuracy:60.630    best:62.090
# learning_rate: 0.1
# Network:2    epoch:27    accuracy:61.700    best:62.090
# learning_rate: 0.1
# Network:1    epoch:28    accuracy:59.030    best:62.090
# learning_rate: 0.1
# Network:2    epoch:28    accuracy:59.500    best:62.090
# learning_rate: 0.1
# Network:1    epoch:29    accuracy:57.870    best:62.090
# learning_rate: 0.1
# Network:2    epoch:29    accuracy:62.270    best:62.270
# learning_rate: 0.010000000000000002
# Network:1    epoch:30    accuracy:69.040    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:30    accuracy:68.480    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:31    accuracy:68.910    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:31    accuracy:68.850    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:32    accuracy:68.880    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:32    accuracy:68.740    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:33    accuracy:68.960    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:33    accuracy:68.680    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:34    accuracy:68.550    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:34    accuracy:68.740    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:35    accuracy:68.490    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:35    accuracy:68.900    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:36    accuracy:68.550    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:36    accuracy:68.870    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:37    accuracy:68.600    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:37    accuracy:68.490    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:38    accuracy:68.460    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:38    accuracy:68.780    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:39    accuracy:68.580    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:39    accuracy:68.410    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:40    accuracy:68.680    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:40    accuracy:68.740    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:41    accuracy:68.530    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:41    accuracy:68.760    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:42    accuracy:68.300    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:42    accuracy:68.480    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:43    accuracy:68.650    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:43    accuracy:68.870    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:44    accuracy:68.750    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:44    accuracy:68.610    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:45    accuracy:68.260    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:45    accuracy:68.530    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:46    accuracy:68.720    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:46    accuracy:68.280    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:47    accuracy:68.460    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:47    accuracy:68.590    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:48    accuracy:68.760    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:48    accuracy:68.610    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:49    accuracy:68.480    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:49    accuracy:68.670    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:50    accuracy:68.790    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:50    accuracy:68.360    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:51    accuracy:68.540    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:51    accuracy:68.250    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:52    accuracy:68.070    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:52    accuracy:68.350    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:53    accuracy:68.460    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:53    accuracy:68.560    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:54    accuracy:68.680    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:54    accuracy:68.560    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:55    accuracy:68.610    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:55    accuracy:68.210    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:56    accuracy:68.470    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:56    accuracy:68.360    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:57    accuracy:68.530    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:57    accuracy:68.070    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:58    accuracy:68.290    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:58    accuracy:68.090    best:69.040
# learning_rate: 0.010000000000000002
# Network:1    epoch:59    accuracy:68.210    best:69.040
# learning_rate: 0.010000000000000002
# Network:2    epoch:59    accuracy:68.280    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:60    accuracy:68.620    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:60    accuracy:68.650    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:61    accuracy:68.830    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:61    accuracy:68.720    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:62    accuracy:68.830    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:62    accuracy:68.660    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:63    accuracy:68.770    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:63    accuracy:68.670    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:64    accuracy:68.870    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:64    accuracy:68.750    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:65    accuracy:68.730    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:65    accuracy:68.910    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:66    accuracy:68.780    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:66    accuracy:68.770    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:67    accuracy:68.870    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:67    accuracy:68.820    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:68    accuracy:68.960    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:68    accuracy:68.900    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:69    accuracy:68.860    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:69    accuracy:68.930    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:70    accuracy:68.750    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:70    accuracy:68.880    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:71    accuracy:68.740    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:71    accuracy:68.780    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:72    accuracy:68.800    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:72    accuracy:68.850    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:73    accuracy:68.730    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:73    accuracy:68.700    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:74    accuracy:68.830    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:74    accuracy:68.990    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:75    accuracy:68.620    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:75    accuracy:68.890    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:76    accuracy:68.820    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:76    accuracy:68.760    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:77    accuracy:68.770    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:77    accuracy:68.830    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:78    accuracy:68.820    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:78    accuracy:68.810    best:69.040
# learning_rate: 0.0010000000000000002
# Network:1    epoch:79    accuracy:68.820    best:69.040
# learning_rate: 0.0010000000000000002
# Network:2    epoch:79    accuracy:68.740    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:80    accuracy:68.960    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:80    accuracy:68.830    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:81    accuracy:68.740    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:81    accuracy:68.780    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:82    accuracy:68.790    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:82    accuracy:68.730    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:83    accuracy:68.830    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:83    accuracy:68.880    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:84    accuracy:68.770    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:84    accuracy:68.900    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:85    accuracy:68.760    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:85    accuracy:68.800    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:86    accuracy:68.870    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:86    accuracy:68.710    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:87    accuracy:68.850    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:87    accuracy:68.830    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:88    accuracy:68.780    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:88    accuracy:68.820    best:69.040
# learning_rate: 0.00010000000000000003
# Network:1    epoch:89    accuracy:68.950    best:69.040
# learning_rate: 0.00010000000000000003
# Network:2    epoch:89    accuracy:69.000    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:90    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:90    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:91    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:91    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:92    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:92    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:93    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:93    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:94    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:94    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:95    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:95    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:96    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:96    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:97    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:97    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:98    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:98    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:99    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:99    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:100    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:100    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:101    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:101    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:102    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:102    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:103    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:103    accuracy:68.660    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:104    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:104    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:105    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:105    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:106    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:106    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:107    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:107    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:108    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:108    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:109    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:109    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:110    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:110    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:111    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:111    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:112    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:112    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:113    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:113    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:114    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:114    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:115    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:115    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:116    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:116    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:117    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:117    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:118    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:118    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:1    epoch:119    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000003e-05
# Network:2    epoch:119    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:120    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:120    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:121    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:121    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:122    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:122    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:123    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:123    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:124    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:124    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:125    accuracy:68.690    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:125    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:126    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:126    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:127    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:127    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:128    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:128    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:129    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:129    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:130    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:130    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:131    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:131    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:132    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:132    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:133    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:133    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:134    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:134    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:135    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:135    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:136    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:136    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:137    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:137    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:138    accuracy:68.610    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:138    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:139    accuracy:68.970    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:139    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:140    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:140    accuracy:69.030    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:141    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:141    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:142    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:142    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:143    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:143    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:144    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:144    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:145    accuracy:68.990    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:145    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:146    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:146    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:147    accuracy:68.610    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:147    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:148    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:148    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:1    epoch:149    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000004e-06
# Network:2    epoch:149    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:150    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:150    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:151    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:151    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:152    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:152    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:153    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:153    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:154    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:154    accuracy:68.640    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:155    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:155    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:156    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:156    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:157    accuracy:69.000    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:157    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:158    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:158    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:159    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:159    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:160    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:160    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:161    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:161    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:162    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:162    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:163    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:163    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:164    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:164    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:165    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:165    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:166    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:166    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:167    accuracy:68.990    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:167    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:168    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:168    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:169    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:169    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:170    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:170    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:171    accuracy:69.020    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:171    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:172    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:172    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:173    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:173    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:174    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:174    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:175    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:175    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:176    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:176    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:177    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:177    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:178    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:178    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:1    epoch:179    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-07
# Network:2    epoch:179    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:180    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:180    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:181    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:181    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:182    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:182    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:183    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:183    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:184    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:184    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:185    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:185    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:186    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:186    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:187    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:187    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:188    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:188    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:189    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:189    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:190    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:190    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:191    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:191    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:192    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:192    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:193    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:193    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:194    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:194    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:195    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:195    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:196    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:196    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:197    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:197    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:198    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:198    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:199    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:199    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:200    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:200    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:201    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:201    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:202    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:202    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:203    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:203    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:204    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:204    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:205    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:205    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:206    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:206    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:207    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:207    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:208    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:208    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:1    epoch:209    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000004e-08
# Network:2    epoch:209    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:210    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:210    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:211    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:211    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:212    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:212    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:213    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:213    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:214    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:214    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:215    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:215    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:216    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:216    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:217    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:217    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:218    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:218    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:219    accuracy:69.000    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:219    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:220    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:220    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:221    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:221    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:222    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:222    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:223    accuracy:69.000    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:223    accuracy:68.670    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:224    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:224    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:225    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:225    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:226    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:226    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:227    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:227    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:228    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:228    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:229    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:229    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:230    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:230    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:231    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:231    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:232    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:232    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:233    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:233    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:234    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:234    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:235    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:235    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:236    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:236    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:237    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:237    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:238    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:238    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:1    epoch:239    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000005e-09
# Network:2    epoch:239    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:240    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:240    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:241    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:241    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:242    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:242    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:243    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:243    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:244    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:244    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:245    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:245    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:246    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:246    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:247    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:247    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:248    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:248    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:249    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:249    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:250    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:250    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:251    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:251    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:252    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:252    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:253    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:253    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:254    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:254    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:255    accuracy:68.690    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:255    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:256    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:256    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:257    accuracy:68.730    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:257    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:258    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:258    accuracy:68.780    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:259    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:259    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:260    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:260    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:261    accuracy:68.890    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:261    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:262    accuracy:69.010    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:262    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:263    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:263    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:264    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:264    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:265    accuracy:68.770    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:265    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:266    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:266    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:267    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:267    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:268    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:268    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:1    epoch:269    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-10
# Network:2    epoch:269    accuracy:68.850    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:270    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:270    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:271    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:271    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:272    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:272    accuracy:68.980    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:273    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:273    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:274    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:274    accuracy:68.860    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:275    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:275    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:276    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:276    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:277    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:277    accuracy:68.920    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:278    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:278    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:279    accuracy:68.970    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:279    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:280    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:280    accuracy:68.680    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:281    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:281    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:282    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:282    accuracy:68.950    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:283    accuracy:68.970    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:283    accuracy:68.800    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:284    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:284    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:285    accuracy:68.880    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:285    accuracy:68.960    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:286    accuracy:68.940    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:286    accuracy:68.720    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:287    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:287    accuracy:68.870    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:288    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:288    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:289    accuracy:68.840    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:289    accuracy:68.830    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:290    accuracy:68.900    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:290    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:291    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:291    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:292    accuracy:68.910    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:292    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:293    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:293    accuracy:68.710    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:294    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:294    accuracy:68.750    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:295    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:295    accuracy:68.810    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:296    accuracy:68.760    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:296    accuracy:68.700    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:297    accuracy:68.930    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:297    accuracy:68.690    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:298    accuracy:68.790    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:298    accuracy:68.820    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:1    epoch:299    accuracy:68.740    best:69.040
# learning_rate: 1.0000000000000006e-11
# Network:2    epoch:299    accuracy:68.900    best:69.040
