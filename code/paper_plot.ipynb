# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
x = [78,52.6,25.9]
y1 = [90.602,90.991,88.321]
y2 = [93.826,92.008,90.768]
y3 = [94.131,91.602,91.933]
font2 = {#'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 12,
}
plt.grid(linestyle = "-.",linewidth=0.5)
plt.plot(x, y1, marker='*', ms=10, label="HRank",markerfacecolor='r')
plt.plot(x, y2, marker='8', ms=10, label="P&G",markerfacecolor='g')
plt.plot(x, y3, marker='v', ms=10, label="P&GGD(ours)",markerfacecolor='b')
plt.xticks(rotation=45)
plt.xlabel("FLOP Ratio (%)")
plt.ylabel("Accuracy (%)")
plt.xlim(20,80)                  #设置x轴的范围
plt.ylim(88,95)
plt.legend(loc="upper left")
plt.savefig("resnet_56_tealeaf.jpg",dpi=600)
plt.show()
